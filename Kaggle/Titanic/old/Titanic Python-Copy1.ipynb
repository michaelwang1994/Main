# %% [markdown]
# # Import

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 999)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")
import re
import csv
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder
import string
# Out:
# /Users/hechengwang/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
train = pd.read_csv("train.csv", header = 0)
test = pd.read_csv("test.csv", header = 0)

# %% [markdown]
# # Analysis

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
a = 0.8
plt.subplot(3,2,1)
male = train['Survived'][train['Sex'] == 'male'][train['Age'].isnull()].value_counts()
male.plot(kind = 'bar', label = 'male is null', alpha = a)
plt.legend()
plt.subplot(3,2,2)
female = train['Survived'][train['Sex'] == 'female'][train['Age'].isnull()].value_counts()
female.plot(kind = 'bar', label = 'female is null', color = 'r', alpha = a)

plt.subplot(3,2,3)
male_age1 = train['Age'][train['Sex'] == 'male'][train['Survived'] == 0].hist(bins = 16, range = (0,80))
male_age1.set_xlabel('male died age dist')

plt.subplot(3,2,4)
female_age1 = train['Age'][train['Sex'] == 'female'][train['Survived'] == 0].hist(bins = 16, range = (0,100))
female_age1.set_xlabel('female died age dist')

plt.subplot(3,2,5)
male_age2 = train['Age'][train['Sex'] == 'male'][train['Survived'] == 1].hist(bins = 16, range = (0,80))
male_age2.set_xlabel('male survived age dist')

plt.subplot(3,2,6)
female_age2 = train['Age'][train['Sex'] == 'female'][train['Survived'] == 1].hist(bins = 16, range = (0,100))
female_age2.set_xlabel('female survived age dist')
plt.show()

# %%
subset_0 = train[['Survived', 'Age', 'Pclass', 'Fare', 'male', 'female']].dropna()
sns.pairplot(subset_0, hue = 'Survived');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-3ec42b4f4520> in <module>()
# ----> 1 subset_0 = train[['Survived', 'Age', 'Pclass', 'Fare', 'male', 'female']].dropna()
#       2 sns.pairplot(subset_0, hue = 'Survived');
#
# /Users/hechengwang/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1906         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1907             # either boolean or fancy integer index
# -> 1908             return self._getitem_array(key)
#    1909         elif isinstance(key, DataFrame):
#    1910             return self._getitem_frame(key)
#
# /Users/hechengwang/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    1950             return self.take(indexer, axis=0, convert=False)
#    1951         else:
# -> 1952             indexer = self.ix._convert_to_indexer(key, axis=1)
#    1953             return self.take(indexer, axis=1, convert=True)
#    1954
#
# /Users/hechengwang/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1119                 mask = check == -1
#    1120                 if mask.any():
# -> 1121                     raise KeyError('%s not in index' % objarr[mask])
#    1122
#    1123                 return _values_from_object(indexer)
#
# KeyError: "['male' 'female'] not in index"

# %%
subset_1 = train[['Survived', 'Age', 'Pclass', 'Fare']][train['Sex'] == 'male'].dropna()
sns.pairplot(subset_1, hue = 'Survived');

# %%
subset_2 = train[['Survived', 'Age', 'Pclass', 'Fare']][train['Sex'] == 'female'].dropna()
sns.pairplot(subset_2, hue = 'Survived');

# %%
pd.crosstab(train['Cabin'].str.extract("(\w)").fillna(""), train['Survived'])

# %%
df = train.append(test, ignore_index= True)

# %%
df
# Out:
#         Age            Cabin Embarked      Fare                                               Name  Parch  PassengerId  Pclass     Sex  SibSp  Survived              Ticket
# 0     22.00              NaN        S    7.2500                            Braund, Mr. Owen Harris      0            1       3    male      1         0           A/5 21171
# 1     38.00              C85        C   71.2833  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2       1  female      1         1            PC 17599
# 2     26.00              NaN        S    7.9250                             Heikkinen, Miss. Laina      0            3       3  female      0         1    STON/O2. 3101282
# 3     35.00             C123        S   53.1000       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4       1  female      1         1              113803
# 4     35.00              NaN        S    8.0500                           Allen, Mr. William Henry      0            5       3    male      0         0              373450
# 5       NaN              NaN        Q    8.4583                                   Moran, Mr. James      0            6       3    male      0         0              330877
# 6     54.00              E46        S   51.8625                            McCarthy, Mr. Timothy J      0            7       1    male      0         0               17463
# 7      2.00              NaN        S   21.0750                     Palsson, Master. Gosta Leonard      1            8       3    male      3         0              349909
# 8     27.00              NaN        S   11.1333  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2            9       3  female      0         1              347742
# 9     14.00              NaN        C   30.0708                Nasser, Mrs. Nicholas (Adele Achem)      0           10       2  female      1         1              237736
# 10     4.00               G6        S   16.7000                    Sandstrom, Miss. Marguerite Rut      1           11       3  female      1         1             PP 9549
# 11    58.00             C103        S   26.5500                           Bonnell, Miss. Elizabeth      0           12       1  female      0         1              113783
# 12    20.00              NaN        S    8.0500                     Saundercock, Mr. William Henry      0           13       3    male      0         0           A/5. 2151
# 13    39.00              NaN        S   31.2750                        Andersson, Mr. Anders Johan      5           14       3    male      1         0              347082
# 14    14.00              NaN        S    7.8542               Vestrom, Miss. Hulda Amanda Adolfina      0           15       3  female      0         0              350406
# 15    55.00              NaN        S   16.0000                   Hewlett, Mrs. (Mary D Kingcome)       0           16       2  female      0         1              248706
# 16     2.00              NaN        Q   29.1250                               Rice, Master. Eugene      1           17       3    male      4         0              382652
# 17      NaN              NaN        S   13.0000                       Williams, Mr. Charles Eugene      0           18       2    male      0         1              244373
# 18    31.00              NaN        S   18.0000  Vander Planke, Mrs. Julius (Emelia Maria Vande...      0           19       3  female      1         0              345763
# 19      NaN              NaN        C    7.2250                            Masselmani, Mrs. Fatima      0           20       3  female      0         1                2649
# 20    35.00              NaN        S   26.0000                               Fynney, Mr. Joseph J      0           21       2    male      0         0              239865
# 21    34.00              D56        S   13.0000                              Beesley, Mr. Lawrence      0           22       2    male      0         1              248698
# 22    15.00              NaN        Q    8.0292                        McGowan, Miss. Anna "Annie"      0           23       3  female      0         1              330923
# 23    28.00               A6        S   35.5000                       Sloper, Mr. William Thompson      0           24       1    male      0         1              113788
# 24     8.00              NaN        S   21.0750                      Palsson, Miss. Torborg Danira      1           25       3  female      3         0              349909
# 25    38.00              NaN        S   31.3875  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5           26       3  female      1         1              347077
# 26      NaN              NaN        C    7.2250                            Emir, Mr. Farred Chehab      0           27       3    male      0         0                2631
# 27    19.00      C23 C25 C27        S  263.0000                     Fortune, Mr. Charles Alexander      2           28       1    male      3         0               19950
# 28      NaN              NaN        Q    7.8792                      O'Dwyer, Miss. Ellen "Nellie"      0           29       3  female      0         1              330959
# 29      NaN              NaN        S    7.8958                                Todoroff, Mr. Lalio      0           30       3    male      0         0              349216
# 30    40.00              NaN        C   27.7208                           Uruchurtu, Don. Manuel E      0           31       1    male      0         0            PC 17601
# 31      NaN              B78        C  146.5208     Spencer, Mrs. William Augustus (Marie Eugenie)      0           32       1  female      1         1            PC 17569
# 32      NaN              NaN        Q    7.7500                           Glynn, Miss. Mary Agatha      0           33       3  female      0         1              335677
# 33    66.00              NaN        S   10.5000                              Wheadon, Mr. Edward H      0           34       2    male      0         0          C.A. 24579
# 34    28.00              NaN        C   82.1708                            Meyer, Mr. Edgar Joseph      0           35       1    male      1         0            PC 17604
# 35    42.00              NaN        S   52.0000                     Holverson, Mr. Alexander Oskar      0           36       1    male      1         0              113789
# 36      NaN              NaN        C    7.2292                                   Mamee, Mr. Hanna      0           37       3    male      0         1                2677
# 37    21.00              NaN        S    8.0500                           Cann, Mr. Ernest Charles      0           38       3    male      0         0          A./5. 2152
# 38    18.00              NaN        S   18.0000                 Vander Planke, Miss. Augusta Maria      0           39       3  female      2         0              345764
# 39    14.00              NaN        C   11.2417                        Nicola-Yarred, Miss. Jamila      0           40       3  female      1         1                2651
# 40    40.00              NaN        S    9.4750     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)      0           41       3  female      1         0                7546
# 41    27.00              NaN        S   21.0000  Turpin, Mrs. William John Robert (Dorothy Ann ...      0           42       2  female      1         0               11668
# 42      NaN              NaN        C    7.8958                                Kraeff, Mr. Theodor      0           43       3    male      0         0              349253
# 43     3.00              NaN        C   41.5792           Laroche, Miss. Simonne Marie Anne Andree      2           44       2  female      1         1       SC/Paris 2123
# 44    19.00              NaN        Q    7.8792                      Devaney, Miss. Margaret Delia      0           45       3  female      0         1              330958
# 45      NaN              NaN        S    8.0500                           Rogers, Mr. William John      0           46       3    male      0         0     S.C./A.4. 23567
# 46      NaN              NaN        Q   15.5000                                  Lennon, Mr. Denis      0           47       3    male      1         0              370371
# 47      NaN              NaN        Q    7.7500                          O'Driscoll, Miss. Bridget      0           48       3  female      0         1               14311
# 48      NaN              NaN        C   21.6792                                Samaan, Mr. Youssef      0           49       3    male      2         0                2662
# 49    18.00              NaN        S   17.8000      Arnold-Franchi, Mrs. Josef (Josefine Franchi)      0           50       3  female      1         0              349237
# 50     7.00              NaN        S   39.6875                         Panula, Master. Juha Niilo      1           51       3    male      4         0             3101295
# 51    21.00              NaN        S    7.8000                       Nosworthy, Mr. Richard Cater      0           52       3    male      0         0          A/4. 39886
# 52    49.00              D33        C   76.7292           Harper, Mrs. Henry Sleeper (Myna Haxtun)      0           53       1  female      1         1            PC 17572
# 53    29.00              NaN        S   26.0000  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...      0           54       2  female      1         1                2926
# 54    65.00              B30        C   61.9792                     Ostby, Mr. Engelhart Cornelius      1           55       1    male      0         0              113509
# 55      NaN              C52        S   35.5000                                  Woolner, Mr. Hugh      0           56       1    male      0         1               19947
# 56    21.00              NaN        S   10.5000                                  Rugg, Miss. Emily      0           57       2  female      0         1          C.A. 31026
# 57    28.50              NaN        C    7.2292                                Novel, Mr. Mansouer      0           58       3    male      0         0                2697
# 58     5.00              NaN        S   27.7500                       West, Miss. Constance Mirium      2           59       2  female      1         1          C.A. 34651
# 59    11.00              NaN        S   46.9000                 Goodwin, Master. William Frederick      2           60       3    male      5         0             CA 2144
# 60    22.00              NaN        C    7.2292                              Sirayanian, Mr. Orsen      0           61       3    male      0         0                2669
# 61    38.00              B28      NaN   80.0000                                Icard, Miss. Amelie      0           62       1  female      0         1              113572
# 62    45.00              C83        S   83.4750                        Harris, Mr. Henry Birkhardt      0           63       1    male      1         0               36973
# 63     4.00              NaN        S   27.9000                              Skoog, Master. Harald      2           64       3    male      3         0              347088
# 64      NaN              NaN        C   27.7208                              Stewart, Mr. Albert A      0           65       1    male      0         0            PC 17605
# 65      NaN              NaN        C   15.2458                           Moubarek, Master. Gerios      1           66       3    male      1         1                2661
# 66    29.00              F33        S   10.5000                       Nye, Mrs. (Elizabeth Ramell)      0           67       2  female      0         1          C.A. 29395
# 67    19.00              NaN        S    8.1583                           Crease, Mr. Ernest James      0           68       3    male      0         0           S.P. 3464
# 68    17.00              NaN        S    7.9250                    Andersson, Miss. Erna Alexandra      2           69       3  female      4         1             3101281
# 69    26.00              NaN        S    8.6625                                  Kink, Mr. Vincenz      0           70       3    male      2         0              315151
# 70    32.00              NaN        S   10.5000                         Jenkin, Mr. Stephen Curnow      0           71       2    male      0         0          C.A. 33111
# 71    16.00              NaN        S   46.9000                         Goodwin, Miss. Lillian Amy      2           72       3  female      5         0             CA 2144
# 72    21.00              NaN        S   73.5000                               Hood, Mr. Ambrose Jr      0           73       2    male      0         0        S.O.C. 14879
# 73    26.00              NaN        C   14.4542                        Chronopoulos, Mr. Apostolos      0           74       3    male      1         0                2680
# 74    32.00              NaN        S   56.4958                                      Bing, Mr. Lee      0           75       3    male      0         1                1601
# 75    25.00            F G73        S    7.6500                            Moen, Mr. Sigurd Hansen      0           76       3    male      0         0              348123
# 76      NaN              NaN        S    7.8958                                  Staneff, Mr. Ivan      0           77       3    male      0         0              349208
# 77      NaN              NaN        S    8.0500                           Moutal, Mr. Rahamin Haim      0           78       3    male      0         0              374746
# 78     0.83              NaN        S   29.0000                      Caldwell, Master. Alden Gates      2           79       2    male      0         1              248738
# 79    30.00              NaN        S   12.4750                           Dowdell, Miss. Elizabeth      0           80       3  female      0         1              364516
# 80    22.00              NaN        S    9.0000                               Waelens, Mr. Achille      0           81       3    male      0         0              345767
# 81    29.00              NaN        S    9.5000                        Sheerlinck, Mr. Jan Baptist      0           82       3    male      0         1              345779
# 82      NaN              NaN        Q    7.7875                     McDermott, Miss. Brigdet Delia      0           83       3  female      0         1              330932
# 83    28.00              NaN        S   47.1000                            Carrau, Mr. Francisco M      0           84       1    male      0         0              113059
# 84    17.00              NaN        S   10.5000                                Ilett, Miss. Bertha      0           85       2  female      0         1          SO/C 14885
# 85    33.00              NaN        S   15.8500  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...      0           86       3  female      3         1             3101278
# 86    16.00              NaN        S   34.3750                             Ford, Mr. William Neal      3           87       3    male      1         0          W./C. 6608
# 87      NaN              NaN        S    8.0500                      Slocovski, Mr. Selman Francis      0           88       3    male      0         0     SOTON/OQ 392086
# 88    23.00      C23 C25 C27        S  263.0000                         Fortune, Miss. Mabel Helen      2           89       1  female      3         1               19950
# 89    24.00              NaN        S    8.0500                             Celotti, Mr. Francesco      0           90       3    male      0         0              343275
# 90    29.00              NaN        S    8.0500                               Christmann, Mr. Emil      0           91       3    male      0         0              343276
# 91    20.00              NaN        S    7.8542                         Andreasson, Mr. Paul Edvin      0           92       3    male      0         0              347466
# 92    46.00              E31        S   61.1750                        Chaffee, Mr. Herbert Fuller      0           93       1    male      1         0         W.E.P. 5734
# 93    26.00              NaN        S   20.5750                            Dean, Mr. Bertram Frank      2           94       3    male      1         0           C.A. 2315
# 94    59.00              NaN        S    7.2500                                  Coxon, Mr. Daniel      0           95       3    male      0         0              364500
# 95      NaN              NaN        S    8.0500                        Shorney, Mr. Charles Joseph      0           96       3    male      0         0              374910
# 96    71.00               A5        C   34.6542                          Goldschmidt, Mr. George B      0           97       1    male      0         0            PC 17754
# 97    23.00          D10 D12        C   63.3583                    Greenfield, Mr. William Bertram      1           98       1    male      0         1            PC 17759
# 98    34.00              NaN        S   23.0000               Doling, Mrs. John T (Ada Julia Bone)      1           99       2  female      0         1              231919
# 99    34.00              NaN        S   26.0000                                  Kantor, Mr. Sinai      0          100       2    male      1         0              244367
# 100   28.00              NaN        S    7.8958                            Petranec, Miss. Matilda      0          101       3  female      0         0              349245
# 101     NaN              NaN        S    7.8958                   Petroff, Mr. Pastcho ("Pentcho")      0          102       3    male      0         0              349215
# 102   21.00              D26        S   77.2875                          White, Mr. Richard Frasar      1          103       1    male      0         0               35281
# 103   33.00              NaN        S    8.6542                         Johansson, Mr. Gustaf Joel      0          104       3    male      0         0                7540
# 104   37.00              NaN        S    7.9250                     Gustafsson, Mr. Anders Vilhelm      0          105       3    male      2         0             3101276
# 105   28.00              NaN        S    7.8958                              Mionoff, Mr. Stoytcho      0          106       3    male      0         0              349207
# 106   21.00              NaN        S    7.6500                   Salkjelsvik, Miss. Anna Kristine      0          107       3  female      0         1              343120
# 107     NaN              NaN        S    7.7750                             Moss, Mr. Albert Johan      0          108       3    male      0         1              312991
# 108   38.00              NaN        S    7.8958                                    Rekic, Mr. Tido      0          109       3    male      0         0              349249
# 109     NaN              NaN        Q   24.1500                                Moran, Miss. Bertha      0          110       3  female      1         1              371110
# 110   47.00             C110        S   52.0000                     Porter, Mr. Walter Chamberlain      0          111       1    male      0         0              110465
# 111   14.50              NaN        C   14.4542                               Zabour, Miss. Hileni      0          112       3  female      1         0                2665
# 112   22.00              NaN        S    8.0500                             Barton, Mr. David John      0          113       3    male      0         0              324669
# 113   20.00              NaN        S    9.8250                            Jussila, Miss. Katriina      0          114       3  female      1         0                4136
# 114   17.00              NaN        C   14.4583                              Attalah, Miss. Malake      0          115       3  female      0         0                2627
# 115   21.00              NaN        S    7.9250                              Pekoniemi, Mr. Edvard      0          116       3    male      0         0   STON/O 2. 3101294
# 116   70.50              NaN        Q    7.7500                               Connors, Mr. Patrick      0          117       3    male      0         0              370369
# 117   29.00              NaN        S   21.0000                    Turpin, Mr. William John Robert      0          118       2    male      1         0               11668
# 118   24.00          B58 B60        C  247.5208                           Baxter, Mr. Quigg Edmond      1          119       1    male      0         0            PC 17558
# 119    2.00              NaN        S   31.2750                  Andersson, Miss. Ellis Anna Maria      2          120       3  female      4         0              347082
# 120   21.00              NaN        S   73.5000                        Hickman, Mr. Stanley George      0          121       2    male      2         0        S.O.C. 14879
# 121     NaN              NaN        S    8.0500                         Moore, Mr. Leonard Charles      0          122       3    male      0         0           A4. 54510
# 122   32.50              NaN        C   30.0708                               Nasser, Mr. Nicholas      0          123       2    male      1         0              237736
# 123   32.50             E101        S   13.0000                                Webber, Miss. Susan      0          124       2  female      0         1               27267
# 124   54.00              D26        S   77.2875                        White, Mr. Percival Wayland      1          125       1    male      0         0               35281
# 125   12.00              NaN        C   11.2417                       Nicola-Yarred, Master. Elias      0          126       3    male      1         1                2651
# 126     NaN              NaN        Q    7.7500                                McMahon, Mr. Martin      0          127       3    male      0         0              370372
# 127   24.00              NaN        S    7.1417                          Madsen, Mr. Fridtjof Arne      0          128       3    male      0         1             C 17369
# 128     NaN            F E69        C   22.3583                                  Peter, Miss. Anna      1          129       3  female      1         1                2668
# 129   45.00              NaN        S    6.9750                                 Ekstrom, Mr. Johan      0          130       3    male      0         0              347061
# 130   33.00              NaN        C    7.8958                               Drazenoic, Mr. Jozef      0          131       3    male      0         0              349241
# 131   20.00              NaN        S    7.0500                     Coelho, Mr. Domingos Fernandeo      0          132       3    male      0         0  SOTON/O.Q. 3101307
# 132   47.00              NaN        S   14.5000     Robins, Mrs. Alexander A (Grace Charity Laury)      0          133       3  female      1         0           A/5. 3337
# 133   29.00              NaN        S   26.0000      Weisz, Mrs. Leopold (Mathilde Francoise Pede)      0          134       2  female      1         1              228414
# 134   25.00              NaN        S   13.0000                     Sobey, Mr. Samuel James Hayden      0          135       2    male      0         0          C.A. 29178
# 135   23.00              NaN        C   15.0458                                 Richard, Mr. Emile      0          136       2    male      0         0       SC/PARIS 2133
# 136   19.00              D47        S   26.2833                       Newsom, Miss. Helen Monypeny      2          137       1  female      0         1               11752
# 137   37.00             C123        S   53.1000                        Futrelle, Mr. Jacques Heath      0          138       1    male      1         0              113803
# 138   16.00              NaN        S    9.2167                                Osen, Mr. Olaf Elon      0          139       3    male      0         0                7534
# 139   24.00              B86        C   79.2000                                 Giglio, Mr. Victor      0          140       1    male      0         0            PC 17593
# 140     NaN              NaN        C   15.2458                      Boulos, Mrs. Joseph (Sultana)      2          141       3  female      0         0                2678
# 141   22.00              NaN        S    7.7500                           Nysten, Miss. Anna Sofia      0          142       3  female      0         1              347081
# 142   24.00              NaN        S   15.8500  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...      0          143       3  female      1         1    STON/O2. 3101279
# 143   19.00              NaN        Q    6.7500                                Burke, Mr. Jeremiah      0          144       3    male      0         0              365222
# 144   18.00              NaN        S   11.5000                         Andrew, Mr. Edgardo Samuel      0          145       2    male      0         0              231945
# 145   19.00              NaN        S   36.7500                       Nicholls, Mr. Joseph Charles      1          146       2    male      1         0          C.A. 33112
# 146   27.00              NaN        S    7.7958       Andersson, Mr. August Edvard ("Wennerstrom")      0          147       3    male      0         1              350043
# 147    9.00              NaN        S   34.3750                   Ford, Miss. Robina Maggie "Ruby"      2          148       3  female      2         0          W./C. 6608
# 148   36.50               F2        S   26.0000           Navratil, Mr. Michel ("Louis M Hoffman")      2          149       2    male      0         0              230080
# 149   42.00              NaN        S   13.0000                  Byles, Rev. Thomas Roussel Davids      0          150       2    male      0         0              244310
# 150   51.00              NaN        S   12.5250                         Bateman, Rev. Robert James      0          151       2    male      0         0         S.O.P. 1166
# 151   22.00               C2        S   66.6000                  Pears, Mrs. Thomas (Edith Wearne)      0          152       1  female      1         1              113776
# 152   55.50              NaN        S    8.0500                                   Meo, Mr. Alfonzo      0          153       3    male      0         0          A.5. 11206
# 153   40.50              NaN        S   14.5000                    van Billiard, Mr. Austin Blyler      2          154       3    male      0         0            A/5. 851
# 154     NaN              NaN        S    7.3125                              Olsen, Mr. Ole Martin      0          155       3    male      0         0           Fa 265302
# 155   51.00              NaN        C   61.3792                        Williams, Mr. Charles Duane      1          156       1    male      0         0            PC 17597
# 156   16.00              NaN        Q    7.7333                   Gilnagh, Miss. Katherine "Katie"      0          157       3  female      0         1               35851
# 157   30.00              NaN        S    8.0500                                    Corn, Mr. Harry      0          158       3    male      0         0     SOTON/OQ 392090
# 158     NaN              NaN        S    8.6625                                Smiljanic, Mr. Mile      0          159       3    male      0         0              315037
# 159     NaN              NaN        S   69.5500                         Sage, Master. Thomas Henry      2          160       3    male      8         0            CA. 2343
# 160   44.00              NaN        S   16.1000                           Cribb, Mr. John Hatfield      1          161       3    male      0         0              371362
# 161   40.00              NaN        S   15.7500  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...      0          162       2  female      0         1          C.A. 33595
# 162   26.00              NaN        S    7.7750                         Bengtsson, Mr. John Viktor      0          163       3    male      0         0              347068
# 163   17.00              NaN        S    8.6625                                    Calic, Mr. Jovo      0          164       3    male      0         0              315093
# 164    1.00              NaN        S   39.6875                       Panula, Master. Eino Viljami      1          165       3    male      4         0             3101295
# 165    9.00              NaN        S   20.5250    Goldsmith, Master. Frank John William "Frankie"      2          166       3    male      0         1              363291
# 166     NaN              E33        S   55.0000             Chibnall, Mrs. (Edith Martha Bowerman)      1          167       1  female      0         1              113505
# 167   45.00              NaN        S   27.9000    Skoog, Mrs. William (Anna Bernhardina Karlsson)      4          168       3  female      1         0              347088
# 168     NaN              NaN        S   25.9250                                Baumann, Mr. John D      0          169       1    male      0         0            PC 17318
# 169   28.00              NaN        S   56.4958                                      Ling, Mr. Lee      0          170       3    male      0         0                1601
# 170   61.00              B19        S   33.5000                          Van der hoef, Mr. Wyckoff      0          171       1    male      0         0              111240
# 171    4.00              NaN        Q   29.1250                               Rice, Master. Arthur      1          172       3    male      4         0              382652
# 172    1.00              NaN        S   11.1333                       Johnson, Miss. Eleanor Ileen      1          173       3  female      1         1              347742
# 173   21.00              NaN        S    7.9250                          Sivola, Mr. Antti Wilhelm      0          174       3    male      0         0   STON/O 2. 3101280
# 174   56.00               A7        C   30.6958                            Smith, Mr. James Clinch      0          175       1    male      0         0               17764
# 175   18.00              NaN        S    7.8542                             Klasen, Mr. Klas Albin      1          176       3    male      1         0              350404
# 176     NaN              NaN        S   25.4667                      Lefebre, Master. Henry Forbes      1          177       3    male      3         0                4133
# 177   50.00              C49        C   28.7125                         Isham, Miss. Ann Elizabeth      0          178       1  female      0         0            PC 17595
# 178   30.00              NaN        S   13.0000                                 Hale, Mr. Reginald      0          179       2    male      0         0              250653
# 179   36.00              NaN        S    0.0000                                Leonard, Mr. Lionel      0          180       3    male      0         0                LINE
# 180     NaN              NaN        S   69.5500                       Sage, Miss. Constance Gladys      2          181       3  female      8         0            CA. 2343
# 181     NaN              NaN        C   15.0500                                   Pernot, Mr. Rene      0          182       2    male      0         0       SC/PARIS 2131
# 182    9.00              NaN        S   31.3875              Asplund, Master. Clarence Gustaf Hugo      2          183       3    male      4         0              347077
# 183    1.00               F4        S   39.0000                          Becker, Master. Richard F      1          184       2    male      2         1              230136
# 184    4.00              NaN        S   22.0250                Kink-Heilmann, Miss. Luise Gretchen      2          185       3  female      0         1              315153
# 185     NaN              A32        S   50.0000                              Rood, Mr. Hugh Roscoe      0          186       1    male      0         0              113767
# 186     NaN              NaN        Q   15.5000    O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)      0          187       3  female      1         1              370365
# 187   45.00              NaN        S   26.5500      Romaine, Mr. Charles Hallace ("Mr C Rolmane")      0          188       1    male      0         1              111428
# 188   40.00              NaN        Q   15.5000                                   Bourke, Mr. John      1          189       3    male      1         0              364849
# 189   36.00              NaN        S    7.8958                                Turcin, Mr. Stjepan      0          190       3    male      0         0              349247
# 190   32.00              NaN        S   13.0000                                Pinsky, Mrs. (Rosa)      0          191       2  female      0         1              234604
# 191   19.00              NaN        S   13.0000                              Carbines, Mr. William      0          192       2    male      0         0               28424
# 192   19.00              NaN        S    7.8542    Andersen-Jensen, Miss. Carla Christine Nielsine      0          193       3  female      1         1              350046
# 193    3.00               F2        S   26.0000                         Navratil, Master. Michel M      1          194       2    male      1         1              230080
# 194   44.00               B4        C   27.7208          Brown, Mrs. James Joseph (Margaret Tobin)      0          195       1  female      0         1            PC 17610
# 195   58.00              B80        C  146.5208                               Lurette, Miss. Elise      0          196       1  female      0         1            PC 17569
# 196     NaN              NaN        Q    7.7500                                Mernagh, Mr. Robert      0          197       3    male      0         0              368703
# 197   42.00              NaN        S    8.4042                   Olsen, Mr. Karl Siegwart Andreas      1          198       3    male      0         0                4579
# 198     NaN              NaN        Q    7.7500                   Madigan, Miss. Margaret "Maggie"      0          199       3  female      0         1              370370
# 199   24.00              NaN        S   13.0000             Yrois, Miss. Henriette ("Mrs Harbeck")      0          200       2  female      0         0              248747
# 200   28.00              NaN        S    9.5000                     Vande Walle, Mr. Nestor Cyriel      0          201       3    male      0         0              345770
# 201     NaN              NaN        S   69.5500                                Sage, Mr. Frederick      2          202       3    male      8         0            CA. 2343
# 202   34.00              NaN        S    6.4958                         Johanson, Mr. Jakob Alfred      0          203       3    male      0         0             3101264
# 203   45.50              NaN        C    7.2250                               Youseff, Mr. Gerious      0          204       3    male      0         0                2628
# 204   18.00              NaN        S    8.0500                           Cohen, Mr. Gurshon "Gus"      0          205       3    male      0         1            A/5 3540
# 205    2.00               G6        S   10.4625                         Strom, Miss. Telma Matilda      1          206       3  female      0         0              347054
# 206   32.00              NaN        S   15.8500                         Backstrom, Mr. Karl Alfred      0          207       3    male      1         0             3101278
# 207   26.00              NaN        C   18.7875                        Albimona, Mr. Nassef Cassem      0          208       3    male      0         1                2699
# 208   16.00              NaN        Q    7.7500                          Carr, Miss. Helen "Ellen"      0          209       3  female      0         1              367231
# 209   40.00              A31        C   31.0000                                   Blank, Mr. Henry      0          210       1    male      0         1              112277
# 210   24.00              NaN        S    7.0500                                     Ali, Mr. Ahmed      0          211       3    male      0         0  SOTON/O.Q. 3101311
# 211   35.00              NaN        S   21.0000                         Cameron, Miss. Clear Annie      0          212       2  female      0         1        F.C.C. 13528
# 212   22.00              NaN        S    7.2500                             Perkin, Mr. John Henry      0          213       3    male      0         0           A/5 21174
# 213   30.00              NaN        S   13.0000                        Givard, Mr. Hans Kristensen      0          214       2    male      0         0              250646
# 214     NaN              NaN        Q    7.7500                                Kiernan, Mr. Philip      0          215       3    male      1         0              367229
# 215   31.00              D36        C  113.2750                            Newell, Miss. Madeleine      0          216       1  female      1         1               35273
# 216   27.00              NaN        S    7.9250                             Honkanen, Miss. Eliina      0          217       3  female      0         1    STON/O2. 3101283
# 217   42.00              NaN        S   27.0000                       Jacobsohn, Mr. Sidney Samuel      0          218       2    male      1         0              243847
# 218   32.00              D15        C   76.2917                              Bazzani, Miss. Albina      0          219       1  female      0         1               11813
# 219   30.00              NaN        S   10.5000                                 Harris, Mr. Walter      0          220       2    male      0         0           W/C 14208
# 220   16.00              NaN        S    8.0500                     Sunderland, Mr. Victor Francis      0          221       3    male      0         1     SOTON/OQ 392089
# 221   27.00              NaN        S   13.0000                               Bracken, Mr. James H      0          222       2    male      0         0              220367
# 222   51.00              NaN        S    8.0500                            Green, Mr. George Henry      0          223       3    male      0         0               21440
# 223     NaN              NaN        S    7.8958                               Nenkoff, Mr. Christo      0          224       3    male      0         0              349234
# 224   38.00              C93        S   90.0000                       Hoyt, Mr. Frederick Maxfield      0          225       1    male      1         1               19943
# 225   22.00              NaN        S    9.3500                       Berglund, Mr. Karl Ivar Sven      0          226       3    male      0         0             PP 4348
# 226   19.00              NaN        S   10.5000                          Mellors, Mr. William John      0          227       2    male      0         1           SW/PP 751
# 227   20.50              NaN        S    7.2500                    Lovell, Mr. John Hall ("Henry")      0          228       3    male      0         0           A/5 21173
# 228   18.00              NaN        S   13.0000                          Fahlstrom, Mr. Arne Jonas      0          229       2    male      0         0              236171
# 229     NaN              NaN        S   25.4667                            Lefebre, Miss. Mathilde      1          230       3  female      3         0                4133
# 230   35.00              C83        S   83.4750       Harris, Mrs. Henry Birkhardt (Irene Wallach)      0          231       1  female      1         1               36973
# 231   29.00              NaN        S    7.7750                           Larsson, Mr. Bengt Edvin      0          232       3    male      0         0              347067
# 232   59.00              NaN        S   13.5000                          Sjostedt, Mr. Ernst Adolf      0          233       2    male      0         0              237442
# 233    5.00              NaN        S   31.3875                     Asplund, Miss. Lillian Gertrud      2          234       3  female      4         1              347077
# 234   24.00              NaN        S   10.5000                  Leyson, Mr. Robert William Norman      0          235       2    male      0         0          C.A. 29566
# 235     NaN              NaN        S    7.5500                       Harknett, Miss. Alice Phoebe      0          236       3  female      0         0          W./C. 6609
# 236   44.00              NaN        S   26.0000                                  Hold, Mr. Stephen      0          237       2    male      1         0               26707
# 237    8.00              NaN        S   26.2500                   Collyer, Miss. Marjorie "Lottie"      2          238       2  female      0         1          C.A. 31921
# 238   19.00              NaN        S   10.5000                    Pengelly, Mr. Frederick William      0          239       2    male      0         0               28665
# 239   33.00              NaN        S   12.2750                             Hunt, Mr. George Henry      0          240       2    male      0         0          SCO/W 1585
# 240     NaN              NaN        C   14.4542                              Zabour, Miss. Thamine      0          241       3  female      1         0                2665
# 241     NaN              NaN        Q   15.5000                     Murphy, Miss. Katherine "Kate"      0          242       3  female      1         1              367230
# 242   29.00              NaN        S   10.5000                    Coleridge, Mr. Reginald Charles      0          243       2    male      0         0         W./C. 14263
# 243   22.00              NaN        S    7.1250                      Maenpaa, Mr. Matti Alexanteri      0          244       3    male      0         0   STON/O 2. 3101275
# 244   30.00              NaN        C    7.2250                               Attalah, Mr. Sleiman      0          245       3    male      0         0                2694
# 245   44.00              C78        Q   90.0000                        Minahan, Dr. William Edward      0          246       1    male      2         0               19928
# 246   25.00              NaN        S    7.7750              Lindahl, Miss. Agda Thorilda Viktoria      0          247       3  female      0         0              347071
# 247   24.00              NaN        S   14.5000                    Hamalainen, Mrs. William (Anna)      2          248       2  female      0         1              250649
# 248   37.00              D35        S   52.5542                      Beckwith, Mr. Richard Leonard      1          249       1    male      1         1               11751
# 249   54.00              NaN        S   26.0000                      Carter, Rev. Ernest Courtenay      0          250       2    male      1         0              244252
# 250     NaN              NaN        S    7.2500                             Reed, Mr. James George      0          251       3    male      0         0              362316
# 251   29.00               G6        S   10.4625         Strom, Mrs. Wilhelm (Elna Matilda Persson)      1          252       3  female      1         0              347054
# 252   62.00              C87        S   26.5500                          Stead, Mr. William Thomas      0          253       1    male      0         0              113514
# 253   30.00              NaN        S   16.1000                           Lobb, Mr. William Arthur      0          254       3    male      1         0           A/5. 3336
# 254   41.00              NaN        S   20.2125           Rosblom, Mrs. Viktor (Helena Wilhelmina)      2          255       3  female      0         0              370129
# 255   29.00              NaN        C   15.2458            Touma, Mrs. Darwis (Hanne Youssef Razi)      2          256       3  female      0         1                2650
# 256     NaN              NaN        C   79.2000                     Thorne, Mrs. Gertrude Maybelle      0          257       1  female      0         1            PC 17585
# 257   30.00              B77        S   86.5000                               Cherry, Miss. Gladys      0          258       1  female      0         1              110152
# 258   35.00              NaN        C  512.3292                                   Ward, Miss. Anna      0          259       1  female      0         1            PC 17755
# 259   50.00              NaN        S   26.0000                        Parrish, Mrs. (Lutie Davis)      1          260       2  female      0         1              230433
# 260     NaN              NaN        Q    7.7500                                  Smith, Mr. Thomas      0          261       3    male      0         0              384461
# 261    3.00              NaN        S   31.3875                  Asplund, Master. Edvin Rojj Felix      2          262       3    male      4         1              347077
# 262   52.00              E67        S   79.6500                                  Taussig, Mr. Emil      1          263       1    male      1         0              110413
# 263   40.00              B94        S    0.0000                              Harrison, Mr. William      0          264       1    male      0         0              112059
# 264     NaN              NaN        Q    7.7500                                 Henry, Miss. Delia      0          265       3  female      0         0              382649
# 265   36.00              NaN        S   10.5000                                  Reeves, Mr. David      0          266       2    male      0         0          C.A. 17248
# 266   16.00              NaN        S   39.6875                          Panula, Mr. Ernesti Arvid      1          267       3    male      4         0             3101295
# 267   25.00              NaN        S    7.7750                           Persson, Mr. Ernst Ulrik      0          268       3    male      1         1              347083
# 268   58.00             C125        S  153.4625      Graham, Mrs. William Thompson (Edith Junkins)      1          269       1  female      0         1            PC 17582
# 269   35.00              C99        S  135.6333                             Bissette, Miss. Amelia      0          270       1  female      0         1            PC 17760
# 270     NaN              NaN        S   31.0000                              Cairns, Mr. Alexander      0          271       1    male      0         0              113798
# 271   25.00              NaN        S    0.0000                       Tornquist, Mr. William Henry      0          272       3    male      0         1                LINE
# 272   41.00              NaN        S   19.5000          Mellinger, Mrs. (Elizabeth Anne Maidment)      1          273       2  female      0         1              250644
# 273   37.00             C118        C   29.7000                              Natsch, Mr. Charles H      1          274       1    male      0         0            PC 17596
# 274     NaN              NaN        Q    7.7500                         Healy, Miss. Hanora "Nora"      0          275       3  female      0         1              370375
# 275   63.00               D7        S   77.9583                  Andrews, Miss. Kornelia Theodosia      0          276       1  female      1         1               13502
# 276   45.00              NaN        S    7.7500                  Lindblom, Miss. Augusta Charlotta      0          277       3  female      0         0              347073
# 277     NaN              NaN        S    0.0000                        Parkes, Mr. Francis "Frank"      0          278       2    male      0         0              239853
# ...
# 1217  12.00               F4        S   39.0000                       Becker, Miss. Ruth Elizabeth      1         1218       2  female      2       NaN              230136
# 1218  46.00              NaN        C   79.2000        Rosenshine, Mr. George (Mr George Thorne")"      0         1219       1    male      0       NaN            PC 17585
# 1219  29.00              NaN        S   26.0000                      Clarke, Mr. Charles Valentine      0         1220       2    male      1       NaN                2003
# 1220  21.00              NaN        S   13.0000                                Enander, Mr. Ingvar      0         1221       2    male      0       NaN              236854
# 1221  48.00              NaN        S   36.7500  Davies, Mrs. John Morgan (Elizabeth Agnes Mary...      2         1222       2  female      0       NaN          C.A. 33112
# 1222  39.00              A18        C   29.7000                       Dulles, Mr. William Crothers      0         1223       1    male      0       NaN            PC 17580
# 1223    NaN              NaN        C    7.2250                                Thomas, Mr. Tannous      0         1224       3    male      0       NaN                2684
# 1224  19.00              NaN        C   15.7417              Nakid, Mrs. Said (Waika Mary" Mowad)"      1         1225       3  female      1       NaN                2653
# 1225  27.00              NaN        S    7.8958                                      Cor, Mr. Ivan      0         1226       3    male      0       NaN              349229
# 1226  30.00             C106        S   26.0000                           Maguire, Mr. John Edward      0         1227       1    male      0       NaN              110469
# 1227  32.00              NaN        S   13.0000                         de Brito, Mr. Jose Joaquim      0         1228       2    male      0       NaN              244360
# 1228  39.00              NaN        C    7.2292                                  Elias, Mr. Joseph      2         1229       3    male      0       NaN                2675
# 1229  25.00              NaN        S   31.5000                               Denbury, Mr. Herbert      0         1230       2    male      0       NaN          C.A. 31029
# 1230    NaN              NaN        C    7.2292                              Betros, Master. Seman      0         1231       3    male      0       NaN                2622
# 1231  18.00              NaN        S   10.5000                      Fillbrook, Mr. Joseph Charles      0         1232       2    male      0       NaN          C.A. 15185
# 1232  32.00              NaN        S    7.5792                         Lundstrom, Mr. Thure Edvin      0         1233       3    male      0       NaN              350403
# 1233    NaN              NaN        S   69.5500                              Sage, Mr. John George      9         1234       3    male      1       NaN            CA. 2343
# 1234  58.00      B51 B53 B55        C  512.3292  Cardeza, Mrs. James Warburton Martinez (Charlo...      1         1235       1  female      0       NaN            PC 17755
# 1235    NaN              NaN        S   14.5000                van Billiard, Master. James William      1         1236       3    male      1       NaN            A/5. 851
# 1236  16.00              NaN        S    7.6500                        Abelseth, Miss. Karen Marie      0         1237       3  female      0       NaN              348125
# 1237  26.00              NaN        S   13.0000                         Botsford, Mr. William Hull      0         1238       2    male      0       NaN              237670
# 1238  38.00              NaN        C    7.2292    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)      0         1239       3  female      0       NaN                2688
# 1239  24.00              NaN        S   13.5000                                   Giles, Mr. Ralph      0         1240       2    male      0       NaN              248726
# 1240  31.00              NaN        S   21.0000                             Walcroft, Miss. Nellie      0         1241       2  female      0       NaN        F.C.C. 13528
# 1241  45.00          D10 D12        C   63.3583       Greenfield, Mrs. Leo David (Blanche Strouse)      1         1242       1  female      0       NaN            PC 17759
# 1242  25.00              NaN        S   10.5000                          Stokes, Mr. Philip Joseph      0         1243       2    male      0       NaN        F.C.C. 13540
# 1243  18.00              NaN        S   73.5000                                Dibden, Mr. William      0         1244       2    male      0       NaN        S.O.C. 14879
# 1244  49.00              NaN        S   65.0000                                 Herman, Mr. Samuel      2         1245       2    male      1       NaN              220845
# 1245   0.17              NaN        S   20.5750            Dean, Miss. Elizabeth Gladys Millvina""      2         1246       3  female      1       NaN           C.A. 2315
# 1246  50.00              E60        S   26.0000                           Julian, Mr. Henry Forbes      0         1247       1    male      0       NaN              113044
# 1247  59.00             C101        S   51.4792     Brown, Mrs. John Murray (Caroline Lane Lamson)      0         1248       1  female      2       NaN               11769
# 1248    NaN              NaN        S    7.8792                                Lockyer, Mr. Edward      0         1249       3    male      0       NaN                1222
# 1249    NaN              NaN        Q    7.7500                               O'Keefe, Mr. Patrick      0         1250       3    male      0       NaN              368402
# 1250  30.00              NaN        S   15.5500  Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...      0         1251       3  female      1       NaN              349910
# 1251  14.50              NaN        S   69.5500                        Sage, Master. William Henry      2         1252       3    male      8       NaN            CA. 2343
# 1252  24.00              NaN        C   37.0042            Mallet, Mrs. Albert (Antoinette Magnin)      1         1253       2  female      1       NaN     S.C./PARIS 2079
# 1253  31.00              NaN        S   21.0000       Ware, Mrs. John James (Florence Louise Long)      0         1254       2  female      0       NaN            CA 31352
# 1254  27.00              NaN        S    8.6625                                  Strilic, Mr. Ivan      0         1255       3    male      0       NaN              315083
# 1255  25.00              E50        C   55.4417       Harder, Mrs. George Achilles (Dorothy Annan)      0         1256       1  female      1       NaN               11765
# 1256    NaN              NaN        S   69.5500                     Sage, Mrs. John (Annie Bullen)      9         1257       3  female      1       NaN            CA. 2343
# 1257    NaN              NaN        C   14.4583                                  Caram, Mr. Joseph      0         1258       3    male      1       NaN                2689
# 1258  22.00              NaN        S   39.6875       Riihivouri, Miss. Susanna Juhantytar Sanni""      0         1259       3  female      0       NaN             3101295
# 1259  45.00              NaN        C   59.4000            Gibson, Mrs. Leonard (Pauline C Boeson)      1         1260       1  female      0       NaN              112378
# 1260  29.00              NaN        C   13.8583                      Pallas y Castello, Mr. Emilio      0         1261       2    male      0       NaN       SC/PARIS 2147
# 1261  21.00              NaN        S   11.5000                                   Giles, Mr. Edgar      0         1262       2    male      1       NaN               28133
# 1262  31.00          E39 E41        C  134.5000                          Wilson, Miss. Helen Alice      0         1263       1  female      0       NaN               16966
# 1263  49.00      B52 B54 B56        S    0.0000                            Ismay, Mr. Joseph Bruce      0         1264       1    male      0       NaN              112058
# 1264  44.00              NaN        S   13.0000                             Harbeck, Mr. William H      0         1265       2    male      0       NaN              248746
# 1265  54.00              A34        S   81.8583              Dodge, Mrs. Washington (Ruth Vidaver)      1         1266       1  female      1       NaN               33638
# 1266  45.00              NaN        C  262.3750                           Bowen, Miss. Grace Scott      0         1267       1  female      0       NaN            PC 17608
# 1267  22.00              NaN        S    8.6625                                  Kink, Miss. Maria      0         1268       3  female      2       NaN              315152
# 1268  21.00              NaN        S   11.5000                       Cotterill, Mr. Henry Harry""      0         1269       2    male      0       NaN               29107
# 1269  55.00              C39        S   50.0000                        Hipkins, Mr. William Edward      0         1270       1    male      0       NaN                 680
# 1270   5.00              NaN        S   31.3875                        Asplund, Master. Carl Edgar      2         1271       3    male      4       NaN              347077
# 1271    NaN              NaN        Q    7.7500                              O'Connor, Mr. Patrick      0         1272       3    male      0       NaN              366713
# 1272  26.00              NaN        Q    7.8792                                  Foley, Mr. Joseph      0         1273       3    male      0       NaN              330910
# 1273    NaN              NaN        S   14.5000                         Risien, Mrs. Samuel (Emma)      0         1274       3  female      0       NaN              364498
# 1274  19.00              NaN        S   16.1000                McNamee, Mrs. Neal (Eileen O'Leary)      0         1275       3  female      1       NaN              376566
# 1275    NaN              NaN        S   12.8750                     Wheeler, Mr. Edwin Frederick""      0         1276       2    male      0       NaN       SC/PARIS 2159
# 1276  24.00              NaN        S   65.0000                                 Herman, Miss. Kate      2         1277       2  female      1       NaN              220845
# 1277  24.00              NaN        S    7.7750                     Aronsson, Mr. Ernst Axel Algot      0         1278       3    male      0       NaN              349911
# 1278  57.00              NaN        S   13.0000                                    Ashby, Mr. John      0         1279       2    male      0       NaN              244346
# 1279  21.00              NaN        Q    7.7500                               Canavan, Mr. Patrick      0         1280       3    male      0       NaN              364858
# 1280   6.00              NaN        S   21.0750                        Palsson, Master. Paul Folke      1         1281       3    male      3       NaN              349909
# 1281  23.00              B24        S   93.5000                         Payne, Mr. Vivian Ponsonby      0         1282       1    male      0       NaN               12749
# 1282  51.00              D28        S   39.4000     Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1         1283       1  female      0       NaN            PC 17592
# 1283  13.00              NaN        S   20.2500                      Abbott, Master. Eugene Joseph      2         1284       3    male      0       NaN           C.A. 2673
# 1284  47.00              NaN        S   10.5000                               Gilbert, Mr. William      0         1285       2    male      0       NaN          C.A. 30769
# 1285  29.00              NaN        S   22.0250                           Kink-Heilmann, Mr. Anton      1         1286       3    male      3       NaN              315153
# 1286  18.00              C31        S   60.0000     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0         1287       1  female      1       NaN               13695
# 1287  24.00              NaN        Q    7.2500                               Colbert, Mr. Patrick      0         1288       3    male      0       NaN              371109
# 1288  48.00              B41        C   79.2000  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1         1289       1  female      1       NaN               13567
# 1289  22.00              NaN        S    7.7750                     Larsson-Rondberg, Mr. Edvard A      0         1290       3    male      0       NaN              347065
# 1290  31.00              NaN        Q    7.7333                           Conlon, Mr. Thomas Henry      0         1291       3    male      0       NaN               21332
# 1291  30.00               C7        S  164.8667                            Bonnell, Miss. Caroline      0         1292       1  female      0       NaN               36928
# 1292  38.00              NaN        S   21.0000                                    Gale, Mr. Harry      0         1293       2    male      1       NaN               28664
# 1293  22.00              NaN        C   59.4000                     Gibson, Miss. Dorothy Winifred      1         1294       1  female      0       NaN              112378
# 1294  17.00              NaN        S   47.1000                             Carrau, Mr. Jose Pedro      0         1295       1    male      0       NaN              113059
# 1295  43.00              D40        C   27.7208                       Frauenthal, Mr. Isaac Gerald      0         1296       1    male      1       NaN               17765
# 1296  20.00              D38        C   13.8625       Nourney, Mr. Alfred (Baron von Drachstedt")"      0         1297       2    male      0       NaN       SC/PARIS 2166
# 1297  23.00              NaN        S   10.5000                          Ware, Mr. William Jeffery      0         1298       2    male      1       NaN               28666
# 1298  50.00              C80        C  211.5000                         Widener, Mr. George Dunton      1         1299       1    male      1       NaN              113503
# 1299    NaN              NaN        Q    7.7208                    Riordan, Miss. Johanna Hannah""      0         1300       3  female      0       NaN              334915
# 1300   3.00              NaN        S   13.7750                          Peacock, Miss. Treasteall      1         1301       3  female      1       NaN  SOTON/O.Q. 3101315
# 1301    NaN              NaN        Q    7.7500                             Naughton, Miss. Hannah      0         1302       3  female      0       NaN              365237
# 1302  37.00              C78        Q   90.0000    Minahan, Mrs. William Edward (Lillian E Thorpe)      0         1303       1  female      1       NaN               19928
# 1303  28.00              NaN        S    7.7750                     Henriksson, Miss. Jenny Lovisa      0         1304       3  female      0       NaN              347086
# 1304    NaN              NaN        S    8.0500                                 Spector, Mr. Woolf      0         1305       3    male      0       NaN           A.5. 3236
# 1305  39.00             C105        C  108.9000                       Oliva y Ocana, Dona. Fermina      0         1306       1  female      0       NaN            PC 17758
# 1306  38.50              NaN        S    7.2500                       Saether, Mr. Simon Sivertsen      0         1307       3    male      0       NaN  SOTON/O.Q. 3101262
# 1307    NaN              NaN        S    8.0500                                Ware, Mr. Frederick      0         1308       3    male      0       NaN              359309
# 1308    NaN              NaN        C   22.3583                           Peter, Master. Michael J      1         1309       3    male      1       NaN                2668
#
# [1309 rows x 12 columns]

# %%
def clean_data(df):
    
    #gender and embarked binarization
    df = pd.concat([df, pd.get_dummies(df['Sex'])], axis = 1)
    df = pd.concat([df, pd.get_dummies(df['Embarked'].fillna('S'), prefix= 'Embarked')], axis = 1)
    
    #create new feature called famsize
    df['FamilySize'] = df['SibSp'] + df['Parch']
    #fare fix
    df['Fare'] = df['Fare'].map(lambda x: np.nan if x==0 else x)
    df.loc[ (df.Fare.isnull())&(df.Pclass==1),'Fare'] =np.median(df[df['Pclass'] == 1]['Fare'].dropna())
    df.loc[ (df.Fare.isnull())&(df.Pclass==2),'Fare'] =np.median( df[df['Pclass'] == 2]['Fare'].dropna())
    df.loc[ (df.Fare.isnull())&(df.Pclass==3),'Fare'] = np.median(df[df['Pclass'] == 3]['Fare'].dropna())

    df['Fare_Per_Person'] = df['Fare'] / (df['FamilySize'] + 1.0)

    #title
    def substrings_in_string(big_string, substrings):
        for substring in substrings:
            if string.find(big_string, substring) != -1:
                return substring
        print big_string
        return np.nan

    title_list=['Mrs', 'Mr', 'Master', 'Miss', 'Major', 'Rev',
                'Dr', 'Ms', 'Mlle','Col', 'Capt', 'Mme', 'Countess',
                'Don', 'Jonkheer']
    df['Title']=df['Name'].map(lambda x: substrings_in_string(x, title_list))

    #replacing all titles with mr, mrs, miss, master
    def replace_titles(x):
        title=x['Title']
        if title in ['Mr','Don', 'Major', 'Capt', 'Jonkheer', 'Rev', 'Col']:
            return 'Mr'
        elif title in ['Master']:
            return 'Master'
        elif title in ['Countess', 'Mme','Mrs']:
            return 'Mrs'
        elif title in ['Mlle', 'Ms','Miss']:
            return 'Miss'
        elif title =='Dr':
            if x['Sex']=='Male':
                return 'Mr'
            else:
                return 'Mrs'
        elif title =='':
            if x['Sex']=='Male':
                return 'Master'
            else:
                return 'Miss'
        else:
            return title

    df['Title']=df.apply(replace_titles, axis=1)
    df = pd.concat([df, pd.get_dummies(df['Title'], prefix = 'Title')], axis = 1)
    
    #age fix
    df['AgeFill'] = df['Age'].groupby(df['Title']).apply(lambda x: x.fillna(x.mean()))
    
    df['AgeCat']=df['AgeFill']
    df.loc[ (df.AgeFill<=10) ,'AgeCat'] = 'child'
    df.loc[ (df.AgeFill>60),'AgeCat'] = 'aged'
    df.loc[ (df.AgeFill>10) & (df.AgeFill <=30) ,'AgeCat'] = 'adult'
    df.loc[ (df.AgeFill>30) & (df.AgeFill <=60) ,'AgeCat'] = 'senior'
    df = pd.concat([df, pd.get_dummies(df['AgeCat'], prefix = 'Age_Cat')], axis = 1)
    
    #cabin fix
    df['Cabin_Category'] = df['Cabin'].str.extract("(\w)")
    df.loc[ (df.Cabin_Category.isnull())&(df.Pclass==1),'Cabin_Category'] = "C"
    df.loc[ (df.Cabin_Category.isnull())&(df.Pclass==2),'Cabin_Category'] = "F"
    df.loc[ (df.Cabin_Category.isnull())&(df.Pclass==3),'Cabin_Category'] = "F"
    df.loc[ (df.Cabin_Category == "T"), 'Cabin_Category'] = "F"
    df = pd.concat([df, pd.get_dummies(df['Cabin_Category'], prefix = 'Cabin_Cat')], axis = 1)
    
    
    #added features
    df['AgeClass']=df['AgeFill']*df['Pclass']
    df['ClassFare']=df['Pclass']*df['Fare_Per_Person']
    df['HighLow']=df['Pclass']
    df.loc[ (df.Fare_Per_Person<8) ,'HighLow'] = 0
    df.loc[ (df.Fare_Per_Person>=8) ,'HighLow'] = 1
    
#    le = LabelEncoder()
#     le.fit(df['Name'].apply(lambda x: x.split(",")[0]))
#     df['Family_Name'] = le.transform(df['Name'].apply(lambda x: x.split(",")[0]))
    
#     #familyid
#     df['Family_Name'] = df['Name'].apply(lambda x: x.split(",")[0])
#     df['FamilySize'] = df['SibSp'] + df['Parch'] + 1.0
#     df['FamId'] = df['FamilySize'].astype(int).astype(str) + df['Family_Name']
#     df['FamId'] = np.where(df['FamilySize'] < 3, 'Small', df['FamId'])
#     small_fams = df['FamId'].value_counts()[df['FamId'].value_counts() < 3].index
#     df['FamId'] = df['FamId'].apply(lambda x: 'Small' if x in small_fams else x)
#     df = pd.concat([df, pd.get_dummies(df['FamId'], prefix = 'Id')], axis = 1)
    
    
    #ticket
    df['Ticket_New'] = df['Ticket'].apply(lambda x: x[:1])
    df = pd.concat([df, pd.get_dummies(df['Ticket_New'], prefix = "Ticket")], axis = 1)

    df = df.drop(['Name', 'Parch', 'SibSp', 'FamilySize', 'PassengerId', 'Ticket_New',
                  'Age', 'AgeCat', 'Sex', 'Embarked', 'Cabin', 'Cabin_Category', 'Title', 'Ticket'], axis = 1)
    return df

# %%
df_clean = clean_data(df)
x = df_clean[:len(train)].drop('Survived', axis = 1)
y = df_clean['Survived'][:len(train)]

test_new = df_clean[len(train):].drop('Survived', axis = 1)

# %% [markdown]
# # Prediction

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import cross_validation
from sklearn import preprocessing
from sklearn.cross_validation import KFold
from sklearn.metrics import accuracy_score
import scipy
import matplotlib as mpl
from sklearn.linear_model import LogisticRegression
from sklearn.grid_search import GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix
from sklearn.cross_validation import StratifiedShuffleSplit

# %%
print x.dtypes
to_drop = []
x_subset = x.drop(to_drop, axis = 1)
test_new_subset = test_new.drop(to_drop, axis = 1)
x_train, x_test, y_train, y_test = cross_validation.train_test_split(x_subset, y, test_size = .2)
# Out:
# Fare               float64
# Pclass               int64
# female             float64
# male               float64
# Embarked_C         float64
# Embarked_Q         float64
# Embarked_S         float64
# Fare_Per_Person    float64
# Title_Master       float64
# Title_Miss         float64
# Title_Mr           float64
# Title_Mrs          float64
# AgeFill            float64
# Age_Cat_adult      float64
# Age_Cat_aged       float64
# Age_Cat_child      float64
# Age_Cat_senior     float64
# Cabin_Cat_A        float64
# Cabin_Cat_B        float64
# Cabin_Cat_C        float64
# Cabin_Cat_D        float64
# Cabin_Cat_E        float64
# Cabin_Cat_F        float64
# Cabin_Cat_G        float64
# AgeClass           float64
# ClassFare          float64
# HighLow              int64
# Ticket_1           float64
# Ticket_2           float64
# Ticket_3           float64
# Ticket_4           float64
# Ticket_5           float64
# Ticket_6           float64
# Ticket_7           float64
# Ticket_8           float64
# Ticket_9           float64
# Ticket_A           float64
# Ticket_C           float64
# Ticket_F           float64
# Ticket_L           float64
# Ticket_P           float64
# Ticket_S           float64
# Ticket_W           float64
# dtype: object

# %%
clf=RandomForestClassifier(criterion='entropy', min_samples_split=1,
  min_samples_leaf=1, bootstrap=False, oob_score=False, n_jobs=1, random_state=0)
parameters = {'n_estimators':[500],
              'max_depth':[5, 10]}
fitmodel = GridSearchCV(clf, param_grid=parameters, cv=StratifiedShuffleSplit(y_train, \
n_iter=10, test_size=0.2, train_size=None), scoring="accuracy")
fitmodel.fit(x_train, y_train)
fitmodel.best_estimator_, fitmodel.best_params_, fitmodel.best_score_, fitmodel.grid_scores_
# Out:
# (RandomForestClassifier(bootstrap=False, class_weight=None,
#              criterion='entropy', max_depth=5, max_features='auto',
#              max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=1,
#              min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#              oob_score=False, random_state=0, verbose=0, warm_start=False),
#  {'max_depth': 5, 'n_estimators': 500},
#  0.84265734265734271,
#  [mean: 0.84266, std: 0.01221, params: {'n_estimators': 500, 'max_depth': 5},
#   mean: 0.82098, std: 0.02103, params: {'n_estimators': 500, 'max_depth': 10}])

# %%
pd.DataFrame((fitmodel.best_estimator_.feature_importances_), index=x_train.columns).plot(kind = 'bar')

# %%
clf3=LogisticRegression()
parameters = {'C':[0.01, 0.05, 0.1, 0.5, 1]}
fitmodel3 = GridSearchCV(clf3, param_grid=parameters, cv=StratifiedShuffleSplit(y_train, \
n_iter=10, test_size=0.2, train_size=None), scoring="accuracy")
fitmodel3.fit(x_train, y_train)
fitmodel3.best_estimator_, fitmodel3.best_params_, fitmodel3.best_score_, fitmodel3.grid_scores_
# Out:
# (LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#            penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#            verbose=0, warm_start=False),
#  {'C': 1},
#  0.83496503496503494,
#  [mean: 0.76294, std: 0.02788, params: {'C': 0.01},
#   mean: 0.80490, std: 0.03055, params: {'C': 0.05},
#   mean: 0.82098, std: 0.03414, params: {'C': 0.1},
#   mean: 0.83217, std: 0.01769, params: {'C': 0.5},
#   mean: 0.83497, std: 0.01829, params: {'C': 1}])

# %%
clf = fitmodel.best_estimator_
x_train_pred = clf.predict(x_train)
x_test_pred = clf.predict(x_test)
print "train-test accuracy: %s - %s" %(accuracy_score(x_train_pred, y_train), accuracy_score(x_test_pred, y_test))
# Out:
# train-test accuracy: 0.863764044944 - 0.787709497207

# %%
for i in range(1, 11):
    clf=RandomForestClassifier(n_estimators=500, criterion='entropy', max_depth=i, min_samples_split=1,
                               min_samples_leaf=1, max_features='auto',    bootstrap=False, oob_score=False, n_jobs=1, random_state=0,
                               verbose=0)
    clf.fit(x_train, y_train)
    x_train_pred = clf.predict(x_train)
    x_test_pred = clf.predict(x_test)
    print "train-test accuracy: %s - %s %s" %(accuracy_score(x_train_pred, y_train), accuracy_score(x_test_pred, y_test), i)
# Out:
# train-test accuracy: 0.787921348315 - 0.748603351955 1
# train-test accuracy: 0.799157303371 - 0.748603351955 2
# train-test accuracy: 0.825842696629 - 0.765363128492 3
# train-test accuracy: 0.851123595506 - 0.782122905028 4
# train-test accuracy: 0.863764044944 - 0.787709497207 5
# train-test accuracy: 0.88202247191 - 0.804469273743 6
# train-test accuracy: 0.917134831461 - 0.815642458101 7
# train-test accuracy: 0.943820224719 - 0.793296089385 8
# train-test accuracy: 0.946629213483 - 0.793296089385 9
# train-test accuracy: 0.955056179775 - 0.798882681564 10

# %%
for i in range(1, 11):
    clf=XGBClassifier(n_estimators=500, max_depth = i, reg_lambda = 1, reg_alpha = 1, learning_rate = 0.1)
    clf.fit(x_train, y_train)
    x_train_pred = clf.predict(x_train)
    x_test_pred = clf.predict(x_test)
    print "train-test accuracy: %s - %s %s" %(accuracy_score(x_train_pred, y_train), accuracy_score(x_test_pred, y_test), i)
# Out:
# train-test accuracy: 0.86095505618 - 0.787709497207 1
# train-test accuracy: 0.907303370787 - 0.798882681564 2
# train-test accuracy: 0.935393258427 - 0.77094972067 3
# train-test accuracy: 0.956460674157 - 0.787709497207 4
# train-test accuracy: 0.963483146067 - 0.793296089385 5
# train-test accuracy: 0.973314606742 - 0.77094972067 6
# train-test accuracy: 0.969101123596 - 0.759776536313 7
# train-test accuracy: 0.970505617978 - 0.765363128492 8
# train-test accuracy: 0.973314606742 - 0.759776536313 9
# train-test accuracy: 0.973314606742 - 0.759776536313 10

# %%
clf=fitmodel.best_estimator_
output = clf.predict(test_new_subset).astype(int)
test_ids = test['PassengerId']

# %%
predictions_file = open("titanic_20160718.csv", "wb")
open_file_object = csv.writer(predictions_file)
open_file_object.writerow(["PassengerId","Survived"])
open_file_object.writerows(zip(test_ids, output))
predictions_file.close()

# %% [markdown]
# This will result in a prediction accuracy of 79.904%, which is better but not there yet :(
